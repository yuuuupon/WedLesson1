# %%
# colabとドライブを繋げる

from google.colab import drive

drive.mount('/content/gdrive')

# %%
# data_science_streamlitのあるディレクトリを指定
dir_name = '/content/gdrive/MyDrive/テスト/機械学習の理論と実践1/第2回/data_science_streamlit'

# %% [markdown]
# # main_app.pyの作成

# %%
# %%writefile {dir_name}/main_app.py
import streamlit as st

# %% [markdown]
# # 1_page.pyの作成

# %%
dir_name_2 = dir_name + '/pages'

# %%
# %%writefile {dir_name_2}/1_page.py
import streamlit as st

st.write('success')
